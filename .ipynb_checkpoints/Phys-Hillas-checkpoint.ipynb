# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib.patches as patches
import numpy as np
from astropy import units as u
from astropy.units import imperial
imperial.enable()
from astropy.io.misc import yaml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5a8be750bdb2> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 from matplotlib.patches import Rectangle
#       3 import matplotlib.patches as patches
#       4 import numpy as np
#       5 from astropy import units as u
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# x-axis labels
x_dist=[]
x_label=[]

x_dist.append(1.e3)
x_label.append('km')

x_dist.append(1.e6)
x_label.append('$10^{3}$ km')



x_dist.append( (1*u.AU).to(u.m).value)
x_label.append('AE')

x_dist.append( (1*u.pc).to(u.m).value)
x_label.append('pc')

x_dist.append( (1*u.kpc).to(u.m).value)
x_label.append('kpc')

x_dist.append( (1*u.Mpc).to(u.m).value)
x_label.append('Mpc')

print(x_dist, x_label)

# y-axis labels
y_b = []
y_label = []

y_b.append( 1.e-9 )
y_label.append( "nG")

y_b.append( 1.e-6 )
y_label.append( "muG")

y_b.append( 1.e-3 )
y_label.append( "mG")

y_b.append( 1. )
y_label.append( "G")

y_b.append( 1.e3 )
y_label.append( "kG")

y_b.append( 1.e6 )
y_label.append( "MG")

y_b.append( 1.e9 )
y_label.append( "GG")
# Out:
# [1000.0, 1000000.0, 149597870700.0, 3.085677581491367e+16, 3.085677581491367e+19, 3.085677581491367e+22] ['km', '$10^{3}$ km', 'AE', 'pc', 'kpc', 'Mpc']

# %%
def getValue(v, to_unit):
    return v['value']*u.Unit(v['unit']).to(to_unit)

def plotHillasObjects(data, ax):
    """
    plot Hillas objects
    - Markers
    - Circles
    - Boxes
    """
    
    # marker p
    for o, v in data.items():
        # plot label
        plt.text(getValue(v['label_pos_size'], u.m),
             getValue(v['label_pos_magn'], u.G),
             v['label_de'],
             fontsize=20,
             color=v['color'])
        
        # plot object
        if v['type'] == 'Marker':
            r = getValue(v['size'], u.m)
            B = getValue(v['magn'], u.G)
            plt.plot(r, 
                     B, 
                     'o',
                     markerfacecolor=v['color'],
                     markeredgecolor=v['color'])
            print("Plotting Marker", v['label_de'])
            
        elif v['type'] == 'Rectangle':
            r_min = getValue(v['size_min'], u.m)
            r_max = getValue(v['size_max'], u.m)
            B_min = getValue(v['magn_min'], u.G)
            B_max = getValue(v['magn_max'], u.G)
            ax.add_patch( Rectangle((r_min,
                           B_min),
                          r_max-r_min,
                          B_max-B_min,
                          facecolor=v['color']))
            print("Plotting Rectangle", v['label_de'])
            
        elif v['type'] == 'Trapezoid':
            r=[]
            B=[]
            r.append(getValue(v['size_1'], u.m))
            r.append(getValue(v['size_2'], u.m))
            r.append(getValue(v['size_3'], u.m))
            r.append(getValue(v['size_4'], u.m))
            B.append(getValue(v['magn_1'], u.G))
            B.append(getValue(v['magn_2'], u.G))
            B.append(getValue(v['magn_3'], u.G))
            B.append(getValue(v['magn_4'], u.G))
            ax.add_patch(patches.Polygon(
                xy=list(zip(r,B)),
                facecolor=v['color']))
 
            print("Plotting Polygon", v['label_de'])

# %%
def plotMaxAcceleration( Z, 
                        beta, 
                        markercolor="b",
                        lstyle="-"):
    """plot maximum acceleration"""
    
    r = np.linspace(500., 5.e24, 250)
    B = 1.e-6*2. * 1.e5 / ((r * u.m).to(u.pc).value)/Z/beta
    
    plt.plot(r, 
             B,
            color=markercolor,
            linestyle=lstyle)

# %%
with open('HillasObjects.yaml') as f:
    data = yaml.load(f)

# %%
plt.figure(figsize=(16,16))
ax=plt.gca()

plt.xlim( 500., 1.e25)
plt.xscale('log')
plt.xticks(x_dist, 
           x_label, 
           fontsize=20)
plt.xlabel('Grösse',
          fontsize=20)

plt.ylim(0.5e-9, 5.e12)
plt.yscale('log')
plt.yticks(y_b, 
           y_label,
          fontsize=25)

plt.ylabel('Magnetfeld B',
          fontsize=25)

plotMaxAcceleration( 1, 1, "r")
plotMaxAcceleration( 1, 0.01, "r", "--")
plotMaxAcceleration( 26, 1, "b")
plotMaxAcceleration( 26, 0.01, "b", "--")


plotHillasObjects(data, ax)
# Out:
# Plotting Marker LHC
# Plotting Rectangle Weisse Zwerge
# Plotting Rectangle Galaxienhaufen
# Plotting Rectangle Starburst Winde
# Plotting Rectangle Wolf Rayet Sterne
# Plotting Polygon AGN Hotspots
# Plotting Polygon AGN Knots
# Plotting Polygon AGN Lobes
# Plotting Polygon Normale Galaxien
# Plotting Polygon Supernovae
# Plotting Polygon GRBs
# Plotting Polygon LL GRBs/TDE
# Plotting Polygon Neutronensterne
